# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/MrDoga/Machine_Learning/blob/master/Assingment_4.ipynb)

# %%
#Q1.Create a dataframe with your name , age , mail id and phone number and add your friends’s information to the same.

import pandas as pd
import io
import requests
data = {'Name':["bob","tom","jerry","sherry","marry","harry"],'age':[22,23,24,25,26,27]
       ,'p_num':[222234,12343,12354,123456,634534,367245],'mail_id':['abc@gmail.com','acsc@gmail.com','vgc@gmail.com','jklc@gmail.com','asdf@gmail.com','dkkld@gmail.com']}
frame = pd.DataFrame(data)
display (frame)
# Out:
#      Name  age          mail_id   p_num
# 0     bob   22    abc@gmail.com  222234
# 1     tom   23   acsc@gmail.com   12343
# 2   jerry   24    vgc@gmail.com   12354
# 3  sherry   25   jklc@gmail.com  123456
# 4   marry   26   asdf@gmail.com  634534
# 5   harry   27  dkkld@gmail.com  367245

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
print (c)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
c.head(5)#prints first 5 rows of data frame
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
c.head(10)# prints first 10 rows of dataframe
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
c.tail(5)#print last 5 rows of data frame
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
c['MinTemp'].sum()#prints the sum of mintemp column
# Out:
# 2659.2000000000003

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
c['MinTemp'].mean()#prints the mean of mintemp column
# Out:
# 7.265573770491804

# %%
import pandas as pd
import io
import requests
c=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
c['MinTemp'].median()#prints the median of mintemp column
# Out:
# 7.45
